# %%
# Installing kafka-pythob Library
# !pip install kafka-python

# %%
# !pip install s3fs

# %%
# Importing Essential libraries
import pandas as pd
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
from s3fs import S3FileSystem
import json

# %%
# Staring & connecting the consumer to Kafka Server/Instance/Broker
consumer = KafkaConsumer(
    'Demo_Test', # Topic name - Repl Factor 1, Partition 1
     bootstrap_servers=['13.201.83.68:9092'], # add your Public IP here
    value_deserializer=lambda x: loads(x.decode('utf-8'))) # deseralizing/decode

# %%
for c in consumer:
    print(c.value)

# %%
s3 = S3FileSystem(key="AKIA4CEZVBNWYLYKNQHO",secret="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")

# %%
for count,i in enumerate(consumer):
    print(count,'\n',i.value)
# Out:
# 0
#  {'Index': 'N100', 'Date': '2007-12-17', 'Open': 982.210022, 'High': 984.059998, 'Low': 976.840027, 'Close': 980.26001, 'Adj Close': 980.26001, 'Volume': 332361400.0, 'CloseUSD': 1195.9172122}
# 1
#  {'Index': 'GSPTSE', 'Date': '1985-10-11', 'Open': 2610.0, 'High': 2619.800049, 'Low': 2609.899902, 'Close': 2618.199951, 'Adj Close': 2611.550781, 'Volume': 11600000.0, 'CloseUSD': 2173.10595933}
# 2
#  {'Index': 'IXIC', 'Date': '1993-06-30', 'Open': 703.659973, 'High': 705.419983, 'Low': 702.130005, 'Close': 703.950012, 'Adj Close': 703.950012, 'Volume': 265900000.0, 'CloseUSD': 703.950012}
# 3
#  {'Index': 'GSPTSE', 'Date': '2013-11-18', 'Open': 13482.59961, 'High': 13512.5, 'Low': 13441.40039, 'Close': 13458.09961, 'Adj Close': 13458.09961, 'Volume': 14154850000.0, 'CloseUSD': 11170.222676299998}
# 4
# ...

# %%
# Send sample records from producer script, consume here and send it to s3 bucket on aws
for count,i in enumerate(consumer):
    with s3.open("s3://kafka-stockmarket-kunal/stock_market_{}.json".format(count),'w') as file:
        json.dump(i.value,file)
